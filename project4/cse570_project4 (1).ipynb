# %% [markdown]
# # Set up the environment

# %% [markdown]
# clone the repo

# %%
# !git clone https://github.com/zshyang/MeshCNN.git
# Out:
# Cloning into 'MeshCNN'...
# remote: Enumerating objects: 264, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 264 (delta 0), reused 4 (delta 0), pack-reused 259
# Receiving objects: 100% (264/264), 3.77 MiB | 39.43 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %% [markdown]
# Install pytorch and verify the installation is successfule (if you see the following error(ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.2.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.2.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.2.0 which is incompatible.
# fastai 2.7.9 requires torch<1.14,>=1.7, but you have torch 1.2.0 which is incompatible.), it is fine:))

# %%
# !pip install -q torch==1.2.0
# Out:
#      |████████████████████████████████| 748.9 MB 650 bytes/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.2.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.2.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.2.0 which is incompatible.
# fastai 2.7.9 requires torch<1.14,>=1.7, but you have torch 1.2.0 which is incompatible.

# %%
import torch

# %% [markdown]
# # Run the experiment

# %%
# %cd MeshCNN
# Out:
# /content/MeshCNN

# %%
# !bash ./scripts/shrec/train.sh
# Out:
# tensorboard X not installed, visualizing wont be available
# ------------ Options -------------
# arch: mconvnet
# batch_size: 16
# beta1: 0.9
# checkpoints_dir: ./checkpoints
# continue_train: False
# dataroot: datasets/shrec_16
# dataset_mode: classification
# epoch_count: 1
# export_folder:
# fc_n: 100
# flip_edges: 0.2
# gpu_ids: [0]
# init_gain: 0.02
# init_type: normal
# is_train: True
# lr: 0.0002
# lr_decay_iters: 50
# lr_policy: lambda
# max_dataset_size: inf
# name: shrec16
# ncf: [64, 128, 256, 256]
# ninput_edges: 750
# niter: 100
# niter_decay: 100
# no_vis: False
# norm: group
# num_aug: 20
# num_groups: 16
# num_threads: 3
# phase: train
# pool_res: [600, 450, 300, 180]
# print_freq: 10
# resblocks: 1
# run_test_freq: 1
# save_epoch_freq: 1
# save_latest_freq: 250
# scale_verts: False
# seed: None
# serial_batches: False
# slide_verts: 0.2
# verbose_plot: False
# which_epoch: latest
# -------------- End ----------------
# computing mean std from train data...
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# 0 of 32
# saved:  datasets/shrec_16/mean_std_cache.p
# loaded mean / std from cache
# #training meshes = 32
# ---------- Network initialized -------------
# [Network] Total number of parameters : 1.321 M
# -----------------------------------------------
# saving the latest model (epoch 1, total_steps 16)
# saving the model at the end of epoch 1, iters 32
# End of epoch 1 / 200 	 Time Taken: 4 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 1, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 2, total_steps 48)
# saving the model at the end of epoch 2, iters 64
# End of epoch 2 / 200 	 Time Taken: 4 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 2, TEST ACC: [50.0 %]
#
# (epoch: 3, iters: 16, time: 0.071, data: 2.191) loss: 0.668
# saving the latest model (epoch 3, total_steps 80)
# saving the model at the end of epoch 3, iters 96
# End of epoch 3 / 200 	 Time Taken: 4 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 3, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 4, total_steps 112)
# saving the model at the end of epoch 4, iters 128
# End of epoch 4 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 4, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 5, total_steps 144)
# (epoch: 5, iters: 32, time: 0.071, data: 0.000) loss: 0.548
# saving the model at the end of epoch 5, iters 160
# End of epoch 5 / 200 	 Time Taken: 4 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 5, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 6, total_steps 176)
# saving the model at the end of epoch 6, iters 192
# End of epoch 6 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 6, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 7, total_steps 208)
# saving the model at the end of epoch 7, iters 224
# End of epoch 7 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 7, TEST ACC: [50.0 %]
#
# (epoch: 8, iters: 16, time: 0.075, data: 1.408) loss: 0.440
# saving the latest model (epoch 8, total_steps 240)
# saving the model at the end of epoch 8, iters 256
# End of epoch 8 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 8, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 9, total_steps 272)
# saving the model at the end of epoch 9, iters 288
# End of epoch 9 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 9, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 10, total_steps 304)
# (epoch: 10, iters: 32, time: 0.070, data: 0.010) loss: 0.448
# saving the model at the end of epoch 10, iters 320
# End of epoch 10 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 10, TEST ACC: [62.5 %]
#
# saving the latest model (epoch 11, total_steps 336)
# saving the model at the end of epoch 11, iters 352
# End of epoch 11 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 11, TEST ACC: [50.0 %]
#
# saving the latest model (epoch 12, total_steps 368)
# saving the model at the end of epoch 12, iters 384
# End of epoch 12 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 12, TEST ACC: [50.0 %]
#
# (epoch: 13, iters: 16, time: 0.082, data: 0.982) loss: 0.297
# saving the latest model (epoch 13, total_steps 400)
# saving the model at the end of epoch 13, iters 416
# End of epoch 13 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 13, TEST ACC: [62.5 %]
#
# saving the latest model (epoch 14, total_steps 432)
# saving the model at the end of epoch 14, iters 448
# End of epoch 14 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 14, TEST ACC: [87.5 %]
#
# saving the latest model (epoch 15, total_steps 464)
# (epoch: 15, iters: 32, time: 0.068, data: 0.008) loss: 0.238
# saving the model at the end of epoch 15, iters 480
# End of epoch 15 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 15, TEST ACC: [100.0 %]
#
# saving the latest model (epoch 16, total_steps 496)
# saving the model at the end of epoch 16, iters 512
# End of epoch 16 / 200 	 Time Taken: 3 sec
# learning rate = 0.0002000
# Running Test
# loaded mean / std from cache
# loading the model from ./checkpoints/shrec16/latest_net.pth
# epoch: 16, TEST ACC: [100.0 %]
#
# saving the latest model (epoch 17, total_steps 528)
# Traceback (most recent call last):
#   File "train.py", line 30, in <module>
#     model.optimize_parameters()
#   File "/content/MeshCNN/models/mesh_classifier.py", line 66, in optimize_parameters
#     out = self.forward()
#   File "/content/MeshCNN/models/mesh_classifier.py", line 57, in forward
#     out = self.net(self.edge_features, self.mesh)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/parallel/data_parallel.py", line 150, in forward
#     return self.module(*inputs[0], **kwargs[0])
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/MeshCNN/models/networks.py", line 150, in forward
#     x = getattr(self, 'pool{}'.format(i))(x, mesh)
#   File "/content/MeshCNN/models/layers/mesh_pool.py", line 21, in __call__
#     return self.forward(fe, meshes)
#   File "/content/MeshCNN/models/layers/mesh_pool.py", line 34, in forward
#     self.__pool_main(mesh_index)
#   File "/content/MeshCNN/models/layers/mesh_pool.py", line 53, in __pool_main
#     self.__pool_edge(mesh, edge_id, mask, edge_groups)
#   File "/content/MeshCNN/models/layers/mesh_pool.py", line 64, in __pool_edge
#     self.__merge_edges[0] = self.__pool_side(mesh, edge_id, mask, edge_groups, 0)
#   File "/content/MeshCNN/models/layers/mesh_pool.py", line 106, in __pool_side
#     self.__redirect_edges(mesh, key_a, side_a - side_a % 2 + 1, other_keys_b[1], mesh.sides[key_b, other_side_b + 1])
# KeyboardInterrupt
